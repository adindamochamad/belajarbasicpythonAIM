# %%
dict={"Nama": "Adinda Panca Mochamad", "Asal": "Surabaya", "Peliharaan": "Kambing"}
biodata={"Nama": "Adinda Panca Mochamad", "Asal": "Surabaya", "Peliharaan": "Kambing"}

print("Namaku adalah", dict["Nama"]) #Print Dictionary
print(biodata)
# Out:
# Namaku adalah Adinda Panca Mochamad
# {'Nama': 'Adinda Panca Mochamad', 'Asal': 'Surabaya', 'Peliharaan': 'Kambing'}

# %%
dict["Umur"]= 20 #Mengubah Value dalam Dictionary
dict["Peliharaan"]= "Sapi" #Menambah Key baru dalam Value

print(dict)
# Out:
# {'Nama': 'Adinda Panca Mochamad', 'Asal': 'Surabaya', 'Peliharaan': 'Sapi', 'Umur': 20}
