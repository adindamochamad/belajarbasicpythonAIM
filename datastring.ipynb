# %%
#Adinda Panca Mochamad
#Institut Teknologi Telkom Surabaya
nama= 'Adinda Panca Mochamad'

print(nama[0:6], nama[12:21])
# Out:
# Adinda  Mochamad

# %%
nama='Persebaya Sidoarjo'
kota='Surabaya'

print('Tim', nama[0:10]+kota)
# Out:
# Tim Persebaya Surabaya

# %%
umur= 20
biodata="Nama Saya Panca dan berumur {}"

print(biodata.format(umur))
# Out:
# Nama Saya Panca dan berumur 20

# %%
#Adinda Panca Mochamad
#Institut Teknologi Telkom Surabaya

listku = ['Mi Goreng','Nasi Goreng','Ayam Panggang']
listmu = ['Matemaika', 'Biologi', 'Kimia']
print(listku[0], listmu[-2])
# Out:
# Mi Goreng Biologi

# %%
listku.pop(1)
print(listku)
# Out:
# ['Mi Goreng', 'Ayam Panggang']

# %%
print(listku)
# Out:
# ['Mi Goreng', 'Ayam Panggang']

# %%
listku.extend(listmu)
print(listku)
# Out:
# ['Mi Goreng', 'Ayam Panggang', 'Matemaika', 'Biologi', 'Kimia', 'Matemaika', 'Biologi', 'Kimia']

# %%
setnama = {'beo', 'jalak', 'garuda', 'nuri', 'unta'}

print(setnama)
print(setnama[-2])
# Out:
# {'unta', 'beo', 'garuda', 'nuri', 'jalak'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-64f139dbee1f> in <module>()
#       2
#       3 print(setnama)
# ----> 4 print(setnama[-2])
#
# TypeError: 'set' object is not subscriptable
