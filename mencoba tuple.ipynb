# %%
#Adinda Panca Mochamad 
#Institut Teknologi Telkom Surabaya
tuple1=("Mobil", "Motor", "Sepeda", "Bus", "Truk")
print(tuple1)
# Out:
# ('Mobil', 'Motor', 'Sepeda', 'Bus', 'Truk')

# %%
print(type(tuple1))
# Out:
# <class 'tuple'>

# %%
tuple1[3]="Pesawat"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-7138226d879c> in <module>()
# ----> 1 tuple1[3]="Pesawat"
#
# TypeError: 'tuple' object does not support item assignment

# %%
hewan=tuple("macan")
print(hewan)
# Out:
# ('m', 'a', 'c', 'a', 'n')

# %%
print(tuple1, hewan)
# Out:
# ('Mobil', 'Motor', 'Sepeda', 'Bus', 'Truk') ('m', 'a', 'c', 'a', 'n')

# %%
print(tuple1[3])
# Out:
# Bus

# %%
bilangan1=(1, 2, 3, 4, 5)
bilangan2=(2, 4, 6, 8, 10)

print(bilangan1 + bilangan2)
# Out:
# (1, 2, 3, 4, 5, 2, 4, 6, 8, 10)

# %%
print(tuple1+bilangan1)
# Out:
# ('Mobil', 'Motor', 'Sepeda', 'Bus', 'Truk', 1, 2, 3, 4, 5)
