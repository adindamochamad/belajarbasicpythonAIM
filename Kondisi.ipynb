# %%
#Adinda Panca Mochamad
#Institut Teknologi Telkom Surabaya

a=1927
b=1930

if b > a:
  print("nilai b lebih besar dari nilai a") #mengkondisikan jika b lebih besar dari a maka yang akan muncul adalah "nilai b lebih besar dari a"
# Out:
# nilai b lebih besar dari nilai a

# %%
c = tuple("makanan")
d = tuple("hewan")

if c>d:
  print("Yak selamat")
# Out:
# Yak selamat

# %%
import math

math.cos(90)
# Out:
# -0.4480736161291701

# %%
import math

math.tan(90)
# Out:
# -1.995200412208242

# %%
import math

x = math.cos(90)
y = math.tan(90)

if x > y:
  print("cos 90 nilainya lebih besar dari tan 90") #Jika memang benar nilai x>y
# Out:
# cos 90 nilainya lebih besar dari tan 90
