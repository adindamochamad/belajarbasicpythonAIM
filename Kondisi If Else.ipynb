# %%
#Adinda Panca Mochamad
#Institut Teknologi Telkom Surabaya

a=10
b=11

if a>=b:
  print("nilai a lebih besar atau sama dari b")

else:
  print("nilai b lebih besar dari a")
# Out:
# nilai b lebih besar dari a

# %%
import math

x = math.cos(180)
y = math.sin(180)

if x>=y:
  print("nilai x lebih besar sama dengan y", x)

else:
  print("nilai y lebih besar daripada x", y)
# Out:
# nilai x lebih besar sama dengan y -0.5984600690578581

# %%
a=14*270
b=17*270

if a>b:
  print("nilai a lebih besar dari b")

else:
  print("nilai b lebih besar dari a")
# Out:
# nilai b lebih besar dari a
